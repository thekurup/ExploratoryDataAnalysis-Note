# %% [markdown]
# #### HOUSE PRICE

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore")

pd.set_option('display.max_rows',20)
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler

# %%
#load
test=pd.read_csv('E:\LEARNING AI\EDA/testhouse.csv')
train=pd.read_csv('E:\LEARNING AI\EDA/trainhouse.csv')

# %%
test
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
#train is used to create model
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train.shape[1]
# Out:
# 81

# %%
train['LotShape'].value_counts()
# Out:
# Reg    925
# IR1    484
# IR2     41
# IR3     10
# Name: LotShape, dtype: int64

# %%
train.drop('Id',axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0             60       RL         65.0     8450   Pave   NaN      Reg
# 1             20       RL         80.0     9600   Pave   NaN      Reg
# 2             60       RL         68.0    11250   Pave   NaN      IR1
# 3             70       RL         60.0     9550   Pave   NaN      IR1
# 4             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 1455          60       RL         62.0     7917   Pave   NaN      Reg
# 1456          20       RL         85.0    13175   Pave   NaN      Reg
# 1457          70       RL         66.0     9042   Pave   NaN      Reg
# 1458          20       RL         68.0     9717   Pave   NaN      Reg
# 1459          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
for i in train:
    if(train[i].isnull().sum() > 0) :
        print(i)
# Out:
# LotFrontage
# Alley
# MasVnrType
# MasVnrArea
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# Electrical
# FireplaceQu
# GarageType
# GarageYrBlt
# GarageFinish
# GarageQual
# GarageCond
# PoolQC
# Fence
# MiscFeature

# %%
null=[i for i in train if (train[i].isnull().sum() >0)]

# %%
null
# Out:
# ['LotFrontage',
#  'Alley',
#  'MasVnrType',
#  'MasVnrArea',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %%
trainNullPer= train.apply(lambda x : np.round(100*x.isnull().sum()/train.shape[0],2))
trainNullCount=train.isnull().sum()
trainNullDF=pd.DataFrame([trainNullCount,trainNullPer]).T

# %%
trainNullDF
# Out:
#                    0      1
# Id               0.0   0.00
# MSSubClass       0.0   0.00
# MSZoning         0.0   0.00
# LotFrontage    259.0  17.74
# LotArea          0.0   0.00
# ...              ...    ...
# MoSold           0.0   0.00
# YrSold           0.0   0.00
# SaleType         0.0   0.00
# SaleCondition    0.0   0.00
# SalePrice        0.0   0.00
#
# [81 rows x 2 columns]

# %%
nullperc= train.apply(lambda x : np.round(x.isnull().sum()/train.shape[0]*100,2))

# %%
nullperc
# Out:
# Id                0.00
# MSSubClass        0.00
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
#                  ...
# MoSold            0.00
# YrSold            0.00
# SaleType          0.00
# SaleCondition     0.00
# SalePrice         0.00
# Length: 81, dtype: float64

# %%
nullcount= train.isnull().sum()

# %%
nullcount
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
data=pd.DataFrame([nullcount,nullperc]).T

# %%
data
# Out:
#                    0      1
# Id               0.0   0.00
# MSSubClass       0.0   0.00
# MSZoning         0.0   0.00
# LotFrontage    259.0  17.74
# LotArea          0.0   0.00
# ...              ...    ...
# MoSold           0.0   0.00
# YrSold           0.0   0.00
# SaleType         0.0   0.00
# SaleCondition    0.0   0.00
# SalePrice        0.0   0.00
#
# [81 rows x 2 columns]

# %%
data.columns=['nullvalues','nullperc']

# %%
data
# Out:
#                nullvalues  nullperc
# Id                    0.0      0.00
# MSSubClass            0.0      0.00
# MSZoning              0.0      0.00
# LotFrontage         259.0     17.74
# LotArea               0.0      0.00
# ...                   ...       ...
# MoSold                0.0      0.00
# YrSold                0.0      0.00
# SaleType              0.0      0.00
# SaleCondition         0.0      0.00
# SalePrice             0.0      0.00
#
# [81 rows x 2 columns]

# %%
data.sort_values(by='nullperc',ascending=False,inplace=True)

# %%
data
# Out:
#              nullvalues  nullperc
# PoolQC           1453.0     99.52
# MiscFeature      1406.0     96.30
# Alley            1369.0     93.77
# Fence            1179.0     80.75
# FireplaceQu       690.0     47.26
# ...                 ...       ...
# ExterQual           0.0      0.00
# Exterior2nd         0.0      0.00
# Exterior1st         0.0      0.00
# RoofMatl            0.0      0.00
# SalePrice           0.0      0.00
#
# [81 rows x 2 columns]

# %%
data.reset_index().head(10)
# Out:
#           index  nullvalues  nullperc
# 0        PoolQC      1453.0     99.52
# 1   MiscFeature      1406.0     96.30
# 2         Alley      1369.0     93.77
# 3         Fence      1179.0     80.75
# 4   FireplaceQu       690.0     47.26
# 5   LotFrontage       259.0     17.74
# 6   GarageYrBlt        81.0      5.55
# 7    GarageCond        81.0      5.55
# 8    GarageType        81.0      5.55
# 9  GarageFinish        81.0      5.55

# %%
train.drop(['PoolQC','MiscFeature','Alley','Fence','FireplaceQu','Id'],axis=1,inplace=True)

# %%
train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
train['MSZoning'].mode()[0]
# Out:
# 'RL'

# %%
for i in train:
    if (train[i].dtype=='object'):
        train[i].fillna(train[i].mode()[0] , inplace=True)
    else:
        train[i].fillna(train[i].median(), inplace=True)

# %%
numc=train.select_dtypes(np.number).columns

# %%
numc
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
j=0
plt.figure(figsize=(40,40))
for column in numc:
    plt.subplot(10,5,j+1)
    plt.scatter(train[column],train['SalePrice'])
    plt.xlabel(column)
    plt.ylabel("HousePrice")
    j+=1

# %%
disc=[]
conc=[]
for i in numc:
    if (train[i].nunique()>20):
        conc.append(i)
    else:
        disc.append(i)

# %%
disc
# Out:
# ['MSSubClass',
#  'OverallQual',
#  'OverallCond',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageCars',
#  '3SsnPorch',
#  'PoolArea',
#  'MoSold',
#  'YrSold']

# %%
conc
# Out:
# ['LotFrontage',
#  'LotArea',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'GarageYrBlt',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  'ScreenPorch',
#  'MiscVal',
#  'SalePrice']

# %%
train['LotFrontage'].describe()
# Out:
# count    1460.000000
# mean       69.863699
# std        22.027677
# min        21.000000
# 25%        60.000000
# 50%        69.000000
# 75%        79.000000
# max       313.000000
# Name: LotFrontage, dtype: float64

# %%
j=0
plt.figure(figsize=(40,40))
for i in conc:
    plt.subplot(10,5,j+1)
    plt.scatter(train[i],train['SalePrice'])
    plt.xlabel(i)
    plt.ylabel('Houseprice')
    j+=1

# %%
j=0
plt.figure(figsize=(40,40))
for i in disc:
    plt.subplot(10,3,j+1)
    plt.scatter(train[i],train['SalePrice'])
    plt.xlabel(i)
    plt.ylabel('houseprice')
    j+=1

# %%
train['OverallQual']
# Out:
# 0       7
# 1       6
# 2       7
# 3       7
# 4       8
#        ..
# 1455    6
# 1456    6
# 1457    7
# 1458    5
# 1459    5
# Name: OverallQual, Length: 1460, dtype: int64

# %%
train['OverallQual'].unique()
# Out:
# array([ 7,  6,  8,  5,  9,  4, 10,  3,  1,  2], dtype=int64)

# %%
train.groupby('OverallQual')['SalePrice'].mean()
# Out:
# OverallQual
# 1      50150.000000
# 2      51770.333333
# 3      87473.750000
# 4     108420.655172
# 5     133523.347607
# 6     161603.034759
# 7     207716.423197
# 8     274735.535714
# 9     367513.023256
# 10    438588.388889
# Name: SalePrice, dtype: float64

# %%
observationVal = train.groupby('OverallQual')['SalePrice'].mean()
observationValDF=pd.DataFrame(observationVal).sort_values(by = 'SalePrice',ascending=False)
observationValDF.reset_index(inplace =True)

# %%
observationValDF
# Out:
#    OverallQual      SalePrice
# 0           10  438588.388889
# 1            9  367513.023256
# 2            8  274735.535714
# 3            7  207716.423197
# 4            6  161603.034759
# 5            5  133523.347607
# 6            4  108420.655172
# 7            3   87473.750000
# 8            2   51770.333333
# 9            1   50150.000000

# %%
j=0
plt.figure(figsize=(40,40))
for i in disc:
    plt.subplot(10,5,j+1)
    ds=train.groupby(i)['SalePrice'].mean()
    dsc=pd.DataFrame(ds).sort_values(by='SalePrice',ascending=False)
    dsc.reset_index(inplace=True)
    plt.bar(dsc[i],dsc['SalePrice'])
    plt.xlabel(i)
    plt.ylabel('houseprice')
    j+=1

# %%
objc=train.select_dtypes(np.object).columns

# %%
objc
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
train['MSZoning'].unique()
# Out:
# array(['RL', 'RM', 'C (all)', 'FV', 'RH'], dtype=object)

# %%
j=0
plt.figure(figsize=(40,40))
for column in objc:
    plt.subplot(10,5,j+1)
    observationVal = train.groupby(column)['SalePrice'].mean()
    observationValDF=pd.DataFrame(observationVal).sort_values(by = 'SalePrice',ascending=False)
    observationValDF.reset_index(inplace =True)
    plt.bar(observationValDF[column],observationValDF['SalePrice'])
    plt.title(f"The House pricee effect on {column}")
    plt.xlabel(column)
    plt.ylabel("HousePrice")
    j+=1

# %%
for column in objc:
    d=train.groupby(i)['SalePrice'].mean()
    x=pd.DataFrame(d).sort_values(by = 'SalePrice',ascending=False)
    x.reset_index(inplace=True)

# %%
x
# Out:
#    YrSold      SalePrice
# 0    2007  186063.151976
# 1    2006  182549.458599
# 2    2009  179432.103550
# 3    2010  177393.674286
# 4    2008  177360.838816

# %%
train['YrSold'].dtype
# Out:
# dtype('int64')

# %%
train.groupby('MSZoning')['SalePrice'].mean()
# Out:
# MSZoning
# C (all)     74528.000000
# FV         214014.061538
# RH         131558.375000
# RL         191004.994787
# RM         126316.830275
# Name: SalePrice, dtype: float64

# %% [markdown]
# HANDLING THE OUTLIER

# %%
for column in conc:
    upper_lim=train[column].mean()+train[column].std() *3
    lower_lim=train[column].mean()-train[column].std() *3

    train.loc[(train[column] > upper_lim),column] = upper_lim
    train.loc[(train[column] < lower_lim),column] = lower_lim

# %%
j=0
plt.figure(figsize=(40,40))
for i in conc:
    plt.subplot(10,5,j+1)
    plt.scatter(train[i],train['SalePrice'])
    plt.xlabel(i)
    plt.ylabel('saleprice')
    j+=1

# %% [markdown]
# #### HANDLING THE CHARCTER MISSING DATA

# %%
objc
# Out:
# Index(['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
#        'PavedDrive', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
trainobj=train[objc]

# %%
trainobj
# Out:
#      MSZoning Street LotShape LandContour Utilities LotConfig LandSlope  \
# 0          RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1          RL   Pave      Reg         Lvl    AllPub       FR2       Gtl
# 2          RL   Pave      IR1         Lvl    AllPub    Inside       Gtl
# 3          RL   Pave      IR1         Lvl    AllPub    Corner       Gtl
# 4          RL   Pave      IR1         Lvl    AllPub       FR2       Gtl
# ...       ...    ...      ...         ...       ...       ...       ...
# 1455       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1456       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1457       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1458       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
# 1459       RL   Pave      Reg         Lvl    AllPub    Inside       Gtl
#
#      Neighborhood Condition1 Condition2  ... Electrical KitchenQual  \
# ...

# %%
from collections import defaultdict

defaultencoder= defaultdict(LabelEncoder)

fittrainobj= trainobj.apply(lambda x: defaultencoder[x.name].fit_transform(x))

# %%
fittrainobj
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1         3            3          0          4
# 1            3       1         3            3          0          2
# 2            3       1         0            3          0          4
# 3            3       1         0            3          0          0
# 4            3       1         0            3          0          2
# ...        ...     ...       ...          ...        ...        ...
# 1455         3       1         3            3          0          4
# 1456         3       1         3            3          0          4
# 1457         3       1         3            3          0          4
# 1458         3       1         3            3          0          4
# 1459         3       1         3            3          0          4
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  Electrical  \
# 0             0             5           2           2  ...           4
# ...

# %%
train.drop(objc,axis=1,inplace=True)

# %%
train
# Out:
#       MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0             60         65.0   8450.0            7            5     2003.0
# 1             20         80.0   9600.0            6            8     1976.0
# 2             60         68.0  11250.0            7            5     2001.0
# 3             70         60.0   9550.0            7            5     1915.0
# 4             60         84.0  14260.0            8            5     2000.0
# ...          ...          ...      ...          ...          ...        ...
# 1455          60         62.0   7917.0            6            5     1999.0
# 1456          20         85.0  13175.0            6            6     1978.0
# 1457          70         66.0   9042.0            7            9     1941.0
# 1458          20         68.0   9717.0            5            6     1950.0
# 1459          20         75.0   9937.0            5            6     1965.0
#
# ...

# %%
updatedTrain= pd.concat([train,fittrainobj],axis=1)

# %%
updttrain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\ARJUNK~1\AppData\Local\Temp/ipykernel_12008/1987404430.py in <module>
# ----> 1 updttrain
#
# NameError: name 'updttrain' is not defined

# %%
corrdf = updatedTrain.corr()

# %%
corrdf
# Out:
#                MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# MSSubClass       1.000000    -0.395731 -0.279702     0.032628    -0.059316
# LotFrontage     -0.395731     1.000000  0.458598     0.235827    -0.059777
# LotArea         -0.279702     0.458598  1.000000     0.181943    -0.015925
# OverallQual      0.032628     0.235827  0.181943     1.000000    -0.091932
# OverallCond     -0.059316    -0.059777 -0.015925    -0.091932     1.000000
# ...                   ...          ...       ...          ...          ...
# GarageQual       0.007630     0.051692  0.019339     0.090562    -0.094761
# GarageCond       0.002927     0.044213  0.038518     0.144988    -0.032236
# PavedDrive      -0.059925     0.095942  0.014115     0.229393    -0.062236
# SaleType         0.012464    -0.032726  0.001833    -0.060472     0.095267
# SaleCondition   -0.024940     0.064632  0.045476     0.193703     0.017758
#
# ...

# %%
corrColumns = abs(corrdf['SalePrice']).sort_values(ascending=False)

# %%
corrColumns[corrColumns>0.4]
# Out:
# SalePrice       1.000000
# OverallQual     0.810469
# GrLivArea       0.722471
# GarageCars      0.663012
# GarageArea      0.650517
# TotalBsmtSF     0.649209
# ExterQual       0.641007
# 1stFlrSF        0.629285
# BsmtQual        0.624198
# KitchenQual     0.590739
# FullBath        0.569415
# GarageFinish    0.558118
# YearBuilt       0.550119
# YearRemodAdd    0.534087
# TotRmsAbvGrd    0.533566
# GarageYrBlt     0.488076
# Fireplaces      0.477834
# MasVnrArea      0.468188
# HeatingQC       0.417038
# Foundation      0.400229
# Name: SalePrice, dtype: float64

# %%
finalColumns = corrColumns[corrColumns>0.4].index

# %%
finalDF = updatedTrain[finalColumns]

# %%
finalDF.head()
# Out:
#    SalePrice  OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  \
# 0   208500.0            7     1710.0           2       548.0        856.0
# 1   181500.0            6     1262.0           2       460.0       1262.0
# 2   223500.0            7     1786.0           2       608.0        920.0
# 3   140000.0            7     1717.0           3       642.0        756.0
# 4   250000.0            8     2198.0           3       836.0       1145.0
#
#    ExterQual  1stFlrSF  BsmtQual  KitchenQual  FullBath  GarageFinish  \
# 0          2     856.0         2            2         2             1
# 1          3    1262.0         2            3         2             1
# 2          2     920.0         2            2         2             1
# 3          3     961.0         3            2         1             2
# 4          2    1145.0         2            2         2             1
#
#    YearBuilt  YearRemodAdd  TotRmsAbvGrd  GarageYrBlt  Fireplaces  MasVnrArea  \
# ...

# %%
y=finalDF['SalePrice']

# %%
x=finalDF.drop('SalePrice',axis=1)

# %%
x
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF  ExterQual  \
# 0               7     1710.0           2       548.0        856.0          2
# 1               6     1262.0           2       460.0       1262.0          3
# 2               7     1786.0           2       608.0        920.0          2
# 3               7     1717.0           3       642.0        756.0          3
# 4               8     2198.0           3       836.0       1145.0          2
# ...           ...        ...         ...         ...          ...        ...
# 1455            6     1647.0           2       460.0        953.0          3
# 1456            6     2073.0           2       500.0       1542.0          3
# 1457            7     2340.0           1       252.0       1152.0          0
# 1458            5     1078.0           1       240.0       1078.0          3
# 1459            5     1256.0           1       276.0       1256.0          2
#
# ...
